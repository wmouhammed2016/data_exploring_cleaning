# %% [markdown]
# # Jupyter Notebooks
#
# ## Objectives
#
# In this notebook, we will cover:
#
# - What is a Jupyter Notebook?
# - Running Cells
# - Cell Types
# - Adding Images to Markdown Cells
# - Command vs. Edit Mode
# - Adding and Deleting Cells
# - Selecting the Kernel
# - Handling the Kernel
# - Stop Execution
# - Restart and Run All
# - Clear Output
# - Autocomplete and Getting Help
# - Call Docstrings
# - IPython Magic Commands
# - Markdown
# - Saving and Sharing

# %% [markdown]
# --------------------------

# %% [markdown]
# ### What is a Jupyter Notebook?
# A Jupyter Notebook is an open-source web application that allows you to create and share documents containing live code, equations, visualizations, and narrative text. It supports various programming languages, including Python, R, and Julia, through the use of "kernels".

# %% [markdown]
# -----------

# %% [markdown]
# ## Running Cells
#
# **Welcome to programming!**
# Juptyer Notebooks (historically called IPython Notebooks) inside **Visual Studio Code** will be our primary tool when conducting data analysis. The first thing to know is that each cell block [of code] can be run be pressing **shift+enter**.
# You could also use the run button on the left side of your cell instead - but we prefer to use our keyboard instead of the mouse;)
# Try running the below code block:

# %%
# Example for running your first code cell 👏🏻
print('This is code being run.')
# Out:
# This is code being run.

# %% [markdown]
# If you want to run more than one cell, you have several options. You can run all cells in the notebook as well as all cells above or below the selected cells by using the icons in the menu bar:

# %% [markdown]
# Red highlights from left to right:
# - run this specific cell
# - run all cells in the notebook
# - run line-by-line / run all cells above this cell / run this cell and all below

# %% [markdown]
# ![jupyter_runseveralcells.png](attachment:jupyter_runseveralcells.png)

# %%
# Try to run all cells above this one / this one and all cells down / cell by cell
print("Hello Minty Floats")
print("Hello once a gain Minty Floats!")
# Out:
# Hello Minty Floats
# Hello once a gain Minty Floats!

# %% [markdown]
# ## Cell Types
#
# You might have started to notice that the code blocks have little notes that say **[ ]:** before you run them, and then are filled with a number after you run them. This is important as it tells you what order cell blocks were run. (Which can sometimes affect how a program runs.)
#
# You may also notice that other cell blocks, such as this one, do not have the **[ ]:** label as the code blocks. This is because this cell block is formatted as **Markdown** (rather then code). They are really useful for embedding notes and explanations in your Jupyter Notebook. You can change what type of cell it is by clicking on the cell and press
# - __ESC+Y__ for code cell format,
# - __ESC+M__ for markdown format.
#
# Note: Jupyter Notebooks can also use Markdown to display images. So don't get confused when we embed screen shots of Jupyter Notebooks in this Jupyter Notebook!
#
# Double clicking on a block of text will show you the Markdown code used to generate it. The idea is similar to HTML code used to render webpages in your browser. Turn the code back into nicely formatted output by pressing **shift+enter**.

# %% [markdown]
# ### Adding Images to Markdown Cells
#
# You can embed images directly in a Markdown cell so they render inline with your notes. Here's how:
#
# 1. Save the image file somewhere your notebook can reach it - for example, in an `images` folder next to your notebook.
# 2. Select the cell and switch it to Markdown mode (**Esc** then **m**).
# 3. Use the Markdown image syntax: `![alt text](path/to/image)`.
# 4. Point the path at your image file. Since `Jupyter_meme.jpg` lives in the `images` folder next to this notebook, you can write:
#
# ```markdown
# ![Jupyter meme](images/Jupyter_meme.jpg)
# ```
#
# 5. Run the cell (**Shift+Enter**) to render the image.

# %% [markdown]
# ![Jupyter meme](images/Jupyter_meme.jpg)

# %% [markdown]
# ## Command Versus Edit Mode
#
# When a cell is selected, we distinguish between two modes, one is the edit mode where you can write code or notes, the other is the command mode where you can delete or copy cells.
#
# To switch from edit mode to command mode, you can press **esc**, (you cannot write in the cell now) and press **Enter** to enter edit mode again.
#
#
# ### Edit Mode
# Edit mode is the standard mode for editing cells, whether it's writing code or notes.
# To enter edit mode from command mode simply hit enter, or double click on a cell.
# The vertical bar to the left of the cell has diagonal lines in this mode.
#
# ### Command Mode
# In command mode, you can delete cells, add cells, copy cells, paste cells, change cell types, and more.
# The vertical bar to the left of the cell is solid in this mode.

# %% [markdown]
# ## Adding and deleting cells
#
# You can add code and markdown cells by clicking on a cell - and hover on its outlines around the middle of the box. They are a bit tricky to find, but when, this two buttons appear:

# %% [markdown]
# ![jupyter_add_cell.png](attachment:jupyter_add_cell.png)

# %% [markdown]
# Wether you hover at the upper or the lower outline, the next cell will be placed before or after the actual cell you clicked.
#
# **Try it out yourself!**

# %% [markdown]
# **Keyboard is The King of Navigation**
#
# Once a cell is selected in **Command Mode** (press **Esc** first), you can manage your notebook entirely from the keyboard:
#
# **Adding a cell**
# - `a` — insert a new cell **above** the selected cell
# - `b` — insert a new cell **below** the selected cell
#
# **Changing the cell type**
# - `m` — convert the selected cell to **Markdown**
# - `y` — convert the selected cell to **Code**
#
# **Deleting a cell**
# - `d` `d` (press **d** twice) — delete the selected cell

# %% [markdown]
# ## Selecting The Kernel
#
# Every Jupyter Notebook needs an engine to actually run your code - that engine is called the **kernel**. Think of the kernel as the "brain" behind your notebook: it's a running process that executes the code in your cells and keeps track of every variable you've defined so far (that's why restarting the kernel wipes your memory! and that's why we need to restart the kernel in some cases).
#
# Before you can start coding, you need to tell your notebook **which Python installation** (and which packages) that brain should use. That's what "selecting a kernel" means.

# %% [markdown]
# **Quick reference**
#
# concept  |  description
# ---|---
# Kernel | The running process that executes your notebook's code and holds its state
# Virtual environment | An isolated Python installation with its own set of packages
# Selecting a kernel | Telling Jupyter which environment (python interpreter + packages) should run your code

# %% [markdown]
# ### What is a Python Virtual Environment?
#
# A **virtual environment** (often shortened to *venv*) is an isolated, self-contained Python installation living in its own folder. Instead of installing every package globally - and risking version conflicts between projects - you create a separate virtual environment for each project with just the packages it needs.
#
# Why this matters for Jupyter:
# - Each virtual environment you create can be registered as its **own Jupyter kernel**.
# - Selecting a kernel is really just telling Jupyter: *"Run this notebook using the Python interpreter and packages from this specific environment."*
# - This keeps your projects clean, reproducible, and free from "it works on my machine" surprises.
#
# You'll typically create a virtual environment with tools like `venv` or `conda`, for example:
#
# ```bash
# # Which python interpreter do we have on our local machine - macOS version
# which -a python3
# /usr/bin/python3 --version
# /usr/local/bin/python3 --version
#
# # Which python interpreter do we have on our local machine - Windows version
# py -0
#
# python3.14 -m venv my_project_env    # How to create the virtual environment on macOS/Linux
# python -3.14 -m venv my_project_env. # How to create the virtual environment on Windows
#
# source my_project_env/bin/activate   # How to activate the virtual environment on macOS/Linux
# my_project_env/Scripts/activate      # How to activate the virtual environment on Windows
#
# # Inside the virtual environment - from the terminal - you can install the ipykernel
# pip install ipykernel       # On both macOS/Linux and Windows
#
# deactivate # How to deactivate - get out of the venv - on both macOS/Linux and Windows
# ```

# %% [markdown]
# ![Diagram showing several isolated Python virtual environments, each with its own set of packages](images/jupyter_venv.png)

# %% [markdown]
# ### How to Select a Kernel in VS Code
#
# Once you have a virtual environment ready (with `ipykernel` installed in it), selecting it as your notebook's kernel takes just a few clicks:
#
# 1. Open your notebook (`.ipynb` file) in VS Code.
# 2. Look at the **top-right corner** of the notebook - you'll see a button showing the currently selected kernel (or "Select Kernel" if none is chosen yet).
# 3. Click that button to open the **kernel picker**.

# %% [markdown]
# ![The kernel selector button in the top-right corner of a VS Code notebook](images/jupyter_selectkernel.png)

# %% [markdown]
# 4. VS Code will show you a list of available kernels, usually grouped by:
#    - **Python Environments** - your virtual environments, conda environments, or global installs
#    - **Existing Jupyter Servers** - remote or already-running Jupyter sessions
#
#    Pick the environment you want to use for this notebook.

# %% [markdown]
# ![Dropdown list showing available Python environments and virtual environments to pick as a kernel](images/jupyter_selectvenv.png)

# %% [markdown]
# 5. Once selected, the kernel's name (and environment) will be displayed in the top-right corner, confirming your notebook is now wired up to that environment.

# %% [markdown]
# ![Top-right corner of a VS Code notebook showing the newly selected kernel name after confirming the choice](images/jupyter_venvname.png)

# %% [markdown]
# ### Double-Checking Your Kernel
#
# Not sure which environment is actually active? Run the cell below - it prints the exact path to the Python interpreter your kernel is using, so you can confirm it matches the virtual environment you selected.

# %%
import sys
print(sys.executable)
# Out:
# /Users/waleed/Documents/NeueFische/da-18-weeks-python-module-amended/.venv/bin/python

# %% [markdown]
# **Try it out!** Create a couple of different virtual environments, register them as kernels (`pip install ipykernel` inside each one), and practice switching between them using the steps above. Notice how the active kernel changes what packages are available to `import`!

# %% [markdown]
# ## Handling the Kernel
# You can use the Notebook Editor toolbar to restart and interrupt the Kernel.

# %% [markdown]
# ### Stop Execution
#
# Long running python processes can be interrupted.

# %% [markdown]
# ![jupyter_interrupt.png](attachment:jupyter_interrupt.png)

# %% [markdown]
# Try it out:

# %%
import time
print("Sleeping")
time.sleep(30) # sleep for a while; interrupt me
print("Done Sleeping")

# %% [markdown]
# Sometimes Notebooks can get a bit chaotic. You might encounter that in your first project. In order for you and others to go through your notebook smoothly, it is important that the cells are executed in the correct order (from top to bottom). To check if this is possible, we recommend that you run **Restart** and **Run All**.

# %% [markdown]
# ![jupyter_restart_runall.png](attachment:jupyter_restart_runall.png)

# %% [markdown]
# When you open a notebook, the cells might have already been executed. Please always **Clear Output** before starting working.

# %% [markdown]
# ![jupyter_clear_output.png](attachment:jupyter_clear_output.png)

# %% [markdown]
# ## Autocomplete and getting Help
#
#
# In VSCode there is an autocomplete function. When you start typing code, you can see a subset of the available commands **when you press tap**. You can use "enter" to auto-complete the first command, otherwise you can use the arrow keys to scroll through all the commands and press "enter" to complete the command.

# %% [markdown]
# ![jupyter_autocomplete.png](attachment:jupyter_autocomplete.png)

# %% [markdown]
# ## Call Docstrings
#
#
# Docstring = Python documentation string; used in class, module, function, or method definition
#
# You can access the docstring by writing **?** after the method and executing the cell:

# %% [markdown]
# ![jupyter_docstring.png](attachment:jupyter_docstring.png)

# %% [markdown]
#  Hovering over a function gives you information about how to use the function correctly.
#
# **Try it out!**

# %% [markdown]
# ## IPython Magic Commands
#
# Many commands influence the Jupyter/IPython session directly. They either interact with the Python interpreter or are executed as shell commands.
#
# command  |  description
# ---|---|
# `ls` | list files
# `cd <dir>` | change directory
# `pwd` | print working directory
# `!<command>` | execute any shell command
# `%hist` | shows all commands typed so far
# `%pprint` | toggles pretty-printing on and off
# `%reset` | restarts the current session

# %%
ls
# Out:
# 01_jupyter_notebooks.ipynb  readme.md
# images/

# %%
pwd
# Out:
# '/Users/waleed/Documents/NeueFische/da-18-weeks-python-module-amended/03_jupyter_notebooks'

# %%
cd ..
# Out:
# /Users/waleed/Documents/NeueFische/da-18-weeks-python-module-amended

# %%
# %hist
# Out:
# # Example for running your first code cell 👏🏻
# print('This is code being run.')
# # Try to run all cells above this one / this one and all cells down / cell by cell
# print("Hello Minty Floats")
# print("Hello once a gain Minty Floats!")
# import sys
# print(sys.executable)
# ls
# pwd
# cd ..
# %hist

# %%
# %pprint
# Out:
# Pretty printing has been turned ON

# %%
# %reset

# %% [markdown]
# ## Markdown
#
# >
# > https://www.markdownguide.org/getting-started/
#
# When you change a Jupyter cell to Markdown (press `Escape` and `m`) then you can start writing your notes...

# %% [markdown]
# -----------

# %% [markdown]
# ### Saving and Sharing:
# You can save your notebook using (Command + S) Ctrl + S shortcut. To share your notebook, you can export it to various formats (HTML, PDF, etc.) through the "File" > "Download as" option.

# %% [markdown]
# ## Summary of Jupyter Shortcuts
#
# Well done - you've covered a lot of ground! Here's a recap of every topic this notebook walked through:
#
# 1. **What is a Jupyter Notebook?** - An interactive, open-source document that mixes live code, text, and visuals, powered by a **kernel**.
# 2. **Running Cells** - Execute a cell with **Shift+Enter**, or use the toolbar to run all cells / everything above / everything below the selected cell.
# 3. **Cell Types** - Cells are either **Code** or **Markdown**; switch between them with `Esc+Y` (code) / `Esc+M` (markdown).
# 4. **Adding Images to Markdown Cells** - Embed pictures with `![alt text](path/to/image)`, pointing at a local file (e.g. an `images` folder next to the notebook).
# 5. **Command vs. Edit Mode** - **Edit mode** lets you type inside a cell; **Command mode** lets you manage cells (add, delete, copy, move). Toggle between them with **Esc** / **Enter**.
# 6. **Adding and Deleting Cells** - Use the hover buttons on a cell's outline, or the keyboard: `a` (insert above), `b` (insert below), `dd` (delete).
# 7. **Selecting the Kernel** - The kernel is the engine that runs your code. Selecting one means telling Jupyter which **Python virtual environment** (interpreter + packages) to use, picked via the kernel selector in the notebook's top-right corner.
# 8. **Handling the Kernel** - Restart or interrupt the kernel from the toolbar whenever you need a clean slate.
# 9. **Stop Execution** - Interrupt a long-running cell without restarting the entire kernel.
# 10. **Restart and Run All** - Re-run the whole notebook top to bottom to confirm it works in the correct order before sharing it.
# 11. **Clear Output** - Clear old outputs before you start working, so you're not misled by stale results.
# 12. **Autocomplete and Getting Help** - Press **Tab** to autocomplete, **Shift+Tab** for instant docstring help.
# 13. **Call Docstrings** - Append `?` to a function/method and run the cell to see its documentation.
# 14. **IPython Magic Commands** - Special `%`-prefixed commands and `!`-prefixed shell commands that interact with the notebook session or your operating system directly from a cell.
# 15. **Markdown** - Format notes with headings, **bold**/*italic* text, links, LaTeX equations, images, and even emojis.
# 16. **Saving and Sharing** - Save with `Ctrl`/`Cmd` + `S`, and export your notebook to HTML, PDF, and more via *File > Download as*.
#
# There are two modes for Jupyter Notebook cells: Command and Edit mode.
# In **Edit mode** (indicated by a green left border) cells act like a normal text editor.
# In **Command mode** (indicated by a blue left border) allows you to edit the notebook, but not type into individual cells.
#
# ### All commands & shortcuts used in this notebook
#
# type  |  command / shortcut  |  description
# ---|---|---
# Notebook shortcut | `Shift` + `Enter` | run the selected cell
# Notebook shortcut | `Esc` | switch from Edit mode to Command mode
# Notebook shortcut | `Enter` | switch from Command mode to Edit mode
# Notebook shortcut | `Tab` | autocomplete / display available attributes
# Notebook shortcut | `Shift` + `Tab` | instant help (docstring popup)
# Notebook shortcut | `a` | insert cell above (Command mode)
# Notebook shortcut | `b` | insert cell below (Command mode)
# Notebook shortcut | `dd` | delete cell (Command mode)
# Notebook shortcut | `c` | copy cell
# Notebook shortcut | `v` | paste cell
# Notebook shortcut | `m` (or `Esc`+`m`) | convert cell to Markdown
# Notebook shortcut | `y` (or `Esc`+`y`) | convert cell to Code
# Notebook shortcut | `Ctrl` + `Shift` + `-` | split cell
# Notebook shortcut | `Shift` + `m` | merge cells
# Notebook shortcut | `Ctrl`/`Cmd` + `S` | save the notebook
# In-cell syntax | `?` after a function/method | show its docstring
# Magic command | `%hist` | show all commands typed so far
# Magic command | `%pprint` | toggle pretty-printing on/off
# Magic command | `%reset` | reset the current session/namespace
# Shell command (in-cell) | `!<command>` | execute any shell command from a cell
# Shell command (in-cell) | `ls` | list files in the current directory
# Shell command (in-cell) | `pwd` | print the working directory
# Shell command (in-cell) | `cd <dir>` | change directory
# Terminal command | `which -a python3` | list all `python3` interpreters on `PATH` (macOS/Linux)
# Terminal command | `python3 --version` | check a Python interpreter's version
# Terminal command | `py -0` | list installed Python versions (Windows)
# Terminal command | `python -m venv <name>` | create a virtual environment
# Terminal command | `source <env>/bin/activate` | activate a virtual environment (macOS/Linux)
# Terminal command | `<env>\Scripts\activate` | activate a virtual environment (Windows)
# Terminal command | `pip install ipykernel` | register a virtual environment as a Jupyter kernel
# Terminal command | `deactivate` | exit the active virtual environment

# %% [markdown]
# ### Jupyter Notebook In Visual Studio Code
# >
# [![Video Explaining how to use Jupyter Notebook in Visual Studio Code](https://img.youtube.com/vi/suAkMeWJ1yE/hqdefault.jpg)](https://www.youtube.com/watch?v=suAkMeWJ1yE)

# %% [markdown]
# ### Jupyter Notebook Running on Local Server

# %% [markdown]
# [![Introduction to Jupyter Notebooks](https://img.youtube.com/vi/HW29067qVWk/hqdefault.jpg)](https://www.youtube.com/watch?v=HW29067qVWk)

# %% [markdown]
# -----------

# %% [markdown]
# ## Check your understanding!
#
# Try to do all these tasks using **shortcuts and commands** rather than the mouse wherever you can. Feel free to experiment with other shortcuts too - the more you practice, the faster they'll become second nature!
#
# 1. Insert a new **code** cell below this one (`b`), and write `pwd` to print the current working directory. Run it with **Shift+Enter**.
# 2. Insert another cell below (`b`) and write `ls` to list the files in this folder. Run it.
# 3. Insert one more cell below and start typing `print(` - press **Tab** to see autocomplete in action, then press **Shift+Tab** to peek at `print`'s docstring without leaving the cell.
# 4. In a new cell, write `print?` and run it to display the full docstring in a separate pane.
# 5. Insert a cell and run the magic command `%hist` to see every command you've typed so far in this session.
# 6. Insert a cell, write `import sys` and `print(sys.executable)`, and run it to confirm which **kernel / virtual environment** is currently active.
# 7. Select one of your cells and switch it to **Markdown** (`m`). Write a short note in **bold** celebrating your progress, then run it.
# 8. **Copy** that markdown cell (`c`) and **paste** it right below (`v`).
# 9. Convert the pasted copy back to a **code** cell (`y`) and write `print('Gratulation! You are now familiar with working with jupyter notebooks!')`. Run it.
# 10. **Delete** two of the extra cells you no longer need (`dd` on each).
# 11. **Save** the notebook (`Ctrl`/`Cmd` + `S`).
# 12. Finally, run **Restart Kernel and Run All** from the toolbar to confirm the whole notebook still runs top to bottom without errors.
#
# --> you're done :)
